# %%
from bs4 import BeautifulSoup as soup  # HTML data structure
from urllib.request import urlopen as uReq  # Web client
import requests

# %%
url =( 'https://www.statsbots.org.bw/motor-vehicle-accident-trend-transport-sector')

# %%
r = requests.get(url)
r.text
# Out:
# '<head><title>Not Acceptable!</title></head><body><h1>Not Acceptable!</h1><p>An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.</p></body></html>'

# %%
web_content = soup(r.text,'1xml')
web_content = web_content.find('div',"class_ = highcharts-container")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-18-dc92e8529e5a> in <module>
# ----> 1 web_content = soup(r.text,'1xml')
#       2 web_content = web_content.find('div',"class_ = highcharts-container")
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     206                     "Couldn't find a tree builder with the features you "
#     207                     "requested: %s. Do you need to install a parser library?"
# --> 208                     % ",".join(features))
#     209
#     210         # At this point either we have a TreeBuilder instance in
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: 1xml. Do you need to install a parser library?
